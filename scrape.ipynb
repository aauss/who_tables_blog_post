# %%
# %load_ext lab_black

# %%
import io
import time
from datetime import date

import pandas as pd
import requests

# %%
def download_who_table() -> pd.DataFrame:
    response = requests.get(
        "https://covid19.who.int/WHO-COVID-19-global-table-data.csv",
    )
    io_stream = io.StringIO(response.content.decode("utf-8"))
    return pd.read_csv(io_stream).rename(
        {"Name": "WHO_Name", "WHO Region": "WHO_Region"}, axis=1
    )

# %%
download_who_table().head()
# Out:
#                    WHO_Name       WHO_Region  Cases - cumulative total  \
# 0                    Global              NaN                 101917147
# 1  United States of America         Americas                  25676612
# 2                     India  South-East Asia                  10746183
# 3                    Brazil         Americas                   9118513
# 4        Russian Federation           Europe                   3832080
#
#    Cases - cumulative total per 1 million population  \
# 0                                       13055.738034
# 1                                       77572.220000
# 2                                        7787.060000
# 3                                       42898.650000
# 4                                       26258.910000
#
#    Cases - newly reported in last 7 days  \
# 0                                3707744
# 1                                1072287
# 2                                  91650
# 3                                 364593
# 4                                 133807
#
#    Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 0                                   504486                    2205515
# 1                                   164415                     433173
# 2                                    13052                     154274
# 3                                    59826                     222666
# 4                                    19032                      72697
#
#    Deaths - cumulative total per 1 million population  \
# 0                                          282.52975
# 1                                         1308.67000
# 2                                          111.79000
# 3                                         1047.55000
# 4                                          498.15000
#
#    Deaths - newly reported in last 7 days  \
# 0                                   95722
# 1                                   22506
# 2                                     935
# 3                                    7423
# 4                                    3726
#
#    Deaths - newly reported in last 24 hours Transmission Classification
# 0                                     13449                         NaN
# 1                                      3521      Community transmission
# 2                                       127           Clusters of cases
# 3                                      1119      Community transmission
# 4                                       512           Clusters of cases
